# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp
from scipy import stats
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.stats.api as sms
from pandas.core import datetools
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.graphics import utils

import warnings

warnings.filterwarnings('ignore')
get_ipython().magic('matplotlib inline')
# Out:
# /Users/sunghwanki/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
train = pd.read_csv("../train.csv")
test = pd.read_csv("../test.csv")

# %%
print("Train data : ", train.shape)
print("Test  data : ", test.shape)
# Out:
# Train data :  (1460, 81)
# Test  data :  (1459, 80)

# %%
# train = train.iloc[:,1:] #Id열 제거
train["MSSubClass"] = train["MSSubClass"].astype('str')

# %%
categorical_columns = ["ExterQual", "ExterCond","BsmtQual", "BsmtCond","BsmtFinType1","BsmtFinType2","HeatingQC","KitchenQual","FireplaceQu","GarageQual","GarageCond","PoolQC"]

for c in categorical_columns:
    train[c][(train[c] == "Ex") | (train[c] == "GLQ")] = 10
    train[c][(train[c] == "Gd") | (train[c] == "ALQ")] = 8
    train[c][(train[c] == "TA") | (train[c] == "BLQ")] = 6
    train[c][(train[c] == "Fa") | (train[c] == "Rec")] = 4
    train[c][(train[c] == "Po") | (train[c] == "LwQ")] = 2
    train[c][(train[c] == "NA") | (train[c] == "NaN") |(train[c] == "Unf")] = 0
    train[c] = train[c].astype('float')

# %%
# Categoric and Numerical 변수 분리
numerical_features = []
categorical_features = []
for f in train.columns:
    if train.dtypes[f] != 'object':
        numerical_features.append(f)
    else:
        categorical_features.append(f)

# %%
print("Numerical Features Qty :", len(numerical_features),"\n")
print("Numerical Features : ", numerical_features, "\n\n")
print("Categorical Features Qty :", len(categorical_features),"\n")
print("Categorical Features :", categorical_features)
# Out:
# Numerical Features Qty : 49
#
# Numerical Features :  ['Id', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'HeatingQC', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd', 'Fireplaces', 'FireplaceQu', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice']
#
#
# Categorical Features Qty : 32
#
# Categorical Features : ['MSSubClass', 'MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'Foundation', 'BsmtExposure', 'Heating', 'CentralAir', 'Electrical', 'Functional', 'GarageType', 'GarageFinish', 'PavedDrive', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']

# %%
def detect_outliers(data, feature):
    
    Q1 = np.percentile(data[feature], 25)
    Q3 = np.percentile(data[feature], 75)
    IQR = Q3 - Q1
        
    outlier_lenth = 1.5 * IQR
        
    outliers = data[(data[feature] < Q1 - outlier_lenth) | (data[feature] > Q3 + outlier_lenth)].index.tolist()

    return outliers

# %%
SalePrice_outliers = detect_outliers(train, "SalePrice")
print(SalePrice_outliers)
# Out:
# [11, 53, 58, 112, 151, 161, 178, 185, 224, 231, 278, 309, 313, 320, 321, 336, 349, 378, 389, 440, 473, 477, 481, 496, 515, 527, 585, 591, 608, 642, 644, 654, 661, 664, 678, 688, 691, 702, 718, 769, 774, 798, 803, 825, 877, 898, 987, 990, 1046, 1142, 1169, 1181, 1182, 1228, 1243, 1267, 1268, 1353, 1373, 1388, 1437]

# %%
GrLivArea_outliers = detect_outliers(train, "GrLivArea")
print(GrLivArea_outliers)
# Out:
# [58, 118, 185, 197, 231, 304, 324, 496, 523, 583, 608, 635, 691, 769, 798, 803, 961, 1024, 1031, 1046, 1142, 1169, 1173, 1175, 1182, 1268, 1298, 1312, 1328, 1353, 1386]

# %%
GarageCars_outliers = detect_outliers(train, "GarageArea")
print(GarageCars_outliers)
# Out:
# [178, 224, 270, 317, 408, 581, 664, 718, 803, 825, 1061, 1087, 1142, 1184, 1190, 1228, 1241, 1268, 1298, 1350, 1417]

# %%
OverallQual_outliers = detect_outliers(train, "OverallQual")
print(OverallQual_outliers)
# Out:
# [375, 533]

# %% [markdown]
# ## Missing Data

# %%
ntrain = train.shape[0]
ntest = test.shape[0]
all_data = pd.concat((train, test)).reset_index(drop=True)
print("All data size is {}".format(all_data.shape))
# Out:
# All data size is (2919, 81)

# %%
all_data["PoolQC"] = all_data["PoolQC"].fillna(0)
all_data["MiscFeature"] = all_data["MiscFeature"].fillna("None")
all_data["Alley"] = all_data["Alley"].fillna("None")
all_data["Fence"] = all_data["Fence"].fillna("None")
all_data["FireplaceQu"] = all_data["FireplaceQu"].fillna(0)

# %%
for col in ('GarageType', 'GarageFinish','BsmtExposure'):
    all_data[col] = all_data[col].fillna('None')

for col in ('GarageYrBlt', 'GarageArea', 'GarageCars', 'GarageQual',"GarageCond"):
    all_data[col] = all_data[col].fillna(0)

for col in ('BsmtCond','BsmtQual','BsmtFinType2','BsmtFinType1','BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF','TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath'):
    all_data[col] = all_data[col].fillna(0)


all_data["MasVnrType"] = all_data["MasVnrType"].fillna("None")
all_data["MasVnrArea"] = all_data["MasVnrArea"].fillna(0)

all_data['MSZoning']= all_data["MSZoning"].fillna(all_data['MSZoning'].mode()[0])

all_data['Utilities'] = all_data['Utilities'].fillna(all_data['Utilities'].mode()[0])

all_data['Functional']= all_data["Functional"].fillna("Typ")

all_data["LotFrontage"] = all_data.groupby("Neighborhood")["LotFrontage"].transform(lambda x: x.fillna(x.median()))
all_data["Electrical"] = all_data['Electrical'].fillna(all_data['Electrical'].mode()[0])

all_data["KitchenQual"]=all_data["KitchenQual"].fillna(0)

all_data['Exterior1st'] = all_data['Exterior1st'].fillna(all_data['Exterior1st'].mode()[0])
all_data['Exterior2nd'] = all_data['Exterior2nd'].fillna(all_data['Exterior2nd'].mode()[0])

all_data['SaleType'] = all_data['SaleType'].fillna(all_data['SaleType'].mode()[0])

all_data['MSSubClass'] = all_data['MSSubClass'].fillna("None")

# %% [markdown]
# ## Correlation

# %% [markdown]
# #### 1. numerical features

# %%
train = all_data[:ntrain]
test = all_data[ntrain:]

# %%
corrmat = train.corr()

# %%
f, ax = plt.subplots(figsize = (15,9))
sns.heatmap(corrmat, vmax = 1, square=True)

# %%
k = 25

cor_numerical_cols = corrmat.nlargest(k, 'SalePrice')['SalePrice'].index 
cor_numerical_cols
# Out:
# Index(['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
#        'TotalBsmtSF', '1stFlrSF', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt',
#        'YearRemodAdd', 'MasVnrArea', 'Fireplaces', 'BsmtFinSF1', 'LotFrontage',
#        'WoodDeckSF', '2ndFlrSF', 'OpenPorchSF', 'HalfBath', 'LotArea',
#        'GarageYrBlt', 'BsmtFullBath', 'BsmtUnfSF', 'BedroomAbvGr',
#        'ScreenPorch'],
#       dtype='object')

# %% [markdown]
# #### 2. categorical features

# %%
train_cat = train[categorical_features]
train_y = train['SalePrice']

train_cat = pd.concat([train_y, train_cat], axis=1)
train_cat.tail()
# Out:
#       SalePrice MSSubClass MSZoning Street Alley LotShape LandContour  \
# 1455   175000.0         60       RL   Pave  None      Reg         Lvl
# 1456   210000.0         20       RL   Pave  None      Reg         Lvl
# 1457   266500.0         70       RL   Pave  None      Reg         Lvl
# 1458   142125.0         20       RL   Pave  None      Reg         Lvl
# 1459   147500.0         20       RL   Pave  None      Reg         Lvl
#
#      Utilities LotConfig LandSlope      ...      CentralAir Electrical  \
# 1455    AllPub    Inside       Gtl      ...               Y      SBrkr
# 1456    AllPub    Inside       Gtl      ...               Y      SBrkr
# 1457    AllPub    Inside       Gtl      ...               Y      SBrkr
# 1458    AllPub    Inside       Gtl      ...               Y      FuseA
# 1459    AllPub    Inside       Gtl      ...               Y      SBrkr
#
#      Functional GarageType GarageFinish PavedDrive  Fence MiscFeature  \
# 1455        Typ     Attchd          RFn          Y   None        None
# 1456       Min1     Attchd          Unf          Y  MnPrv        None
# 1457        Typ     Attchd          RFn          Y  GdPrv        Shed
# 1458        Typ     Attchd          Unf          Y   None        None
# 1459        Typ     Attchd          Fin          Y   None        None
#
#      SaleType SaleCondition
# 1455       WD        Normal
# 1456       WD        Normal
# 1457       WD        Normal
# 1458       WD        Normal
# 1459       WD        Normal
#
# [5 rows x 33 columns]

# %%
train_cat_dummy = pd.get_dummies(train_cat)
cat_corrmat = train_cat_dummy.corr()

# %%
k = 10

cor_categorical_cols = cat_corrmat.nlargest(k, 'SalePrice')['SalePrice'].index 
cor_categorical_cols
# Out:
# Index(['SalePrice', 'Foundation_PConc', 'GarageFinish_Fin',
#        'Neighborhood_NridgHt', 'MSSubClass_60', 'SaleType_New',
#        'SaleCondition_Partial', 'GarageType_Attchd', 'MasVnrType_Stone',
#        'Neighborhood_NoRidge'],
#       dtype='object')

# %% [markdown]
# ## First OLS
# - for detecting outliers & Selecting variables

# %%
train = sm.add_constant(train)
train.tail()
# Out:
#       const  1stFlrSF  2ndFlrSF  3SsnPorch Alley  BedroomAbvGr BldgType  \
# 1455    1.0       953       694          0  None             3     1Fam
# 1456    1.0      2073         0          0  None             3     1Fam
# 1457    1.0      1188      1152          0  None             4     1Fam
# 1458    1.0      1078         0          0  None             2     1Fam
# 1459    1.0      1256         0          0  None             3     1Fam
#
#      BsmtCond BsmtExposure  BsmtFinSF1  ...    SaleType ScreenPorch Street  \
# 1455        6           No         0.0  ...          WD           0   Pave
# 1456        6           No       790.0  ...          WD           0   Pave
# 1457        8           No       275.0  ...          WD           0   Pave
# 1458        6           Mn        49.0  ...          WD           0   Pave
# 1459        6           No       830.0  ...          WD           0   Pave
#
#       TotRmsAbvGrd  TotalBsmtSF Utilities  WoodDeckSF YearBuilt YearRemodAdd  \
# 1455             7        953.0    AllPub           0      1999         2000
# 1456             7       1542.0    AllPub         349      1978         1988
# 1457             9       1152.0    AllPub           0      1941         2006
# 1458             5       1078.0    AllPub         366      1950         1996
# 1459             6       1256.0    AllPub         736      1965         1965
#
#      YrSold
# 1455   2007
# 1456   2010
# 1457   2010
# 1458   2010
# 1459   2008
#
# [5 rows x 82 columns]

# %% [markdown]
# ### 1. numerical

# %%
train_n = train[numerical_features]
train_n = train_n.drop(['SalePrice','Id'], axis=1)
train_n.tail()
y_train_l = np.log1p(train_y)

# %%
train_n = train_n.astype('float')

# %%
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(train_n.values, i) for i in range(train_n.values.shape[1])]
vif["features"] = train_n.columns
vif.sort_values("VIF Factor", ascending=True)

#높으면 빼도 되는 것
# Out:
#       VIF Factor       features
# 44  1.042004e+00        MiscVal
# 40  1.046636e+00      3SsnPorch
# 41  1.203658e+00    ScreenPorch
# 23  1.248004e+00   BsmtHalfBath
# 39  1.474228e+00  EnclosedPorch
# 38  1.856737e+00    OpenPorchSF
# 6   1.887391e+00     MasVnrArea
# 37  1.924421e+00     WoodDeckSF
# 1   2.724334e+00        LotArea
# 13  3.273030e+00   BsmtFinType2
# 25  3.511519e+00       HalfBath
# 22  3.973432e+00   BsmtFullBath
# 11  6.435924e+00   BsmtFinType1
# 45  6.684676e+00         MoSold
# 30  9.012235e+00     Fireplaces
# 42  9.061272e+00       PoolArea
# 43  9.618596e+00         PoolQC
# 31  9.728025e+00    FireplaceQu
# 0   1.626114e+01    LotFrontage
# 24  2.677243e+01       FullBath
# 34  3.233793e+01     GarageArea
# 26  3.257377e+01   BedroomAbvGr
# 17  3.317666e+01      HeatingQC
# 27  3.505456e+01   KitchenAbvGr
# 33  4.092289e+01     GarageCars
# 3   4.964880e+01    OverallCond
# 9   7.247819e+01       BsmtQual
# 10  7.464616e+01       BsmtCond
# 2   7.864602e+01    OverallQual
# 28  7.869117e+01    KitchenQual
# 29  8.489385e+01   TotRmsAbvGrd
# 8   9.826377e+01      ExterCond
# 7   1.111659e+02      ExterQual
# 32  2.468978e+02    GarageYrBlt
# 35  2.536301e+02     GarageQual
# 36  2.689203e+02     GarageCond
# 4   1.970151e+04      YearBuilt
# 5   2.490585e+04   YearRemodAdd
# 46  2.997364e+04         YrSold
# 12           inf     BsmtFinSF1
# 14           inf     BsmtFinSF2
# 15           inf      BsmtUnfSF
# 16           inf    TotalBsmtSF
# 21           inf      GrLivArea
# 20           inf   LowQualFinSF
# 18           inf       1stFlrSF
# 19           inf       2ndFlrSF

# %%
train_n = sm.add_constant(train_n)

# %%
model_1 = sm.OLS(y_train_l, train_n)
result_1 = model_1.fit()
print(result_1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.874
# Model:                            OLS   Adj. R-squared:                  0.870
# Method:                 Least Squares   F-statistic:                     218.7
# Date:                Mon, 12 Mar 2018   Prob (F-statistic):               0.00
# Time:                        23:37:49   Log-Likelihood:                 783.04
# No. Observations:                1460   AIC:                            -1474.
# Df Residuals:                    1414   BIC:                            -1231.
# Df Model:                          45
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            17.6307      5.911      2.983      0.003       6.035      29.226
# LotFrontage       0.0004      0.000      1.700      0.089   -5.39e-05       0.001
# LotArea        2.325e-06   4.29e-07      5.424      0.000    1.48e-06    3.17e-06
# OverallQual       0.0671      0.005     12.562      0.000       0.057       0.078
# OverallCond       0.0478      0.005     10.247      0.000       0.039       0.057
# YearBuilt         0.0022      0.000      8.024      0.000       0.002       0.003
# YearRemodAdd      0.0004      0.000      1.265      0.206      -0.000       0.001
# MasVnrArea    -5.358e-06   2.49e-05     -0.216      0.829   -5.41e-05    4.34e-05
# ExterQual         0.0113      0.006      1.966      0.049    2.75e-05       0.023
# ExterCond        -0.0054      0.006     -0.904      0.366      -0.017       0.006
# BsmtQual          0.0125      0.004      2.791      0.005       0.004       0.021
# BsmtCond         -0.0021      0.005     -0.390      0.697      -0.013       0.009
# BsmtFinType1      0.0053      0.001      3.661      0.000       0.002       0.008
# BsmtFinSF1    -4.199e-06   1.48e-05     -0.284      0.777   -3.32e-05    2.48e-05
# BsmtFinType2     -0.0062      0.004     -1.652      0.099      -0.014       0.001
# BsmtFinSF2     5.779e-05   3.06e-05      1.886      0.059    -2.3e-06       0.000
# BsmtUnfSF     -1.024e-05   1.38e-05     -0.742      0.459   -3.73e-05    1.69e-05
# TotalBsmtSF    4.335e-05   1.83e-05      2.375      0.018    7.54e-06    7.92e-05
# HeatingQC         0.0103      0.003      4.031      0.000       0.005       0.015
# 1stFlrSF       9.798e-05   2.65e-05      3.699      0.000     4.6e-05       0.000
# 2ndFlrSF       1.819e-05   2.39e-05      0.761      0.447   -2.87e-05    6.51e-05
# LowQualFinSF   7.485e-06    6.2e-05      0.121      0.904      -0.000       0.000
# GrLivArea         0.0001    2.4e-05      5.155      0.000    7.66e-05       0.000
# BsmtFullBath      0.0433      0.011      3.867      0.000       0.021       0.065
# BsmtHalfBath      0.0124      0.017      0.723      0.470      -0.021       0.046
# FullBath          0.0334      0.012      2.843      0.005       0.010       0.056
# HalfBath          0.0283      0.011      2.530      0.012       0.006       0.050
# BedroomAbvGr      0.0105      0.007      1.454      0.146      -0.004       0.025
# KitchenAbvGr     -0.0576      0.021     -2.763      0.006      -0.098      -0.017
# KitchenQual       0.0129      0.005      2.768      0.006       0.004       0.022
# TotRmsAbvGrd      0.0135      0.005      2.612      0.009       0.003       0.024
# Fireplaces        0.0157      0.013      1.233      0.218      -0.009       0.041
# FireplaceQu       0.0062      0.002      2.732      0.006       0.002       0.011
# GarageYrBlt   -5.096e-05   3.08e-05     -1.657      0.098      -0.000    9.38e-06
# GarageCars        0.0553      0.013      4.408      0.000       0.031       0.080
# GarageArea      4.15e-05   4.12e-05      1.006      0.314   -3.94e-05       0.000
# GarageQual        0.0158      0.010      1.526      0.127      -0.004       0.036
# GarageCond        0.0068      0.011      0.635      0.526      -0.014       0.028
# WoodDeckSF        0.0001   3.33e-05      3.131      0.002     3.9e-05       0.000
# OpenPorchSF   -5.203e-05   6.34e-05     -0.821      0.412      -0.000    7.23e-05
# EnclosedPorch     0.0002   7.05e-05      2.445      0.015    3.41e-05       0.000
# 3SsnPorch         0.0002      0.000      1.364      0.173    -7.8e-05       0.000
# ScreenPorch       0.0003   7.15e-05      4.559      0.000       0.000       0.000
# PoolArea          0.0006      0.000      2.038      0.042    2.16e-05       0.001
# PoolQC           -0.0752      0.022     -3.469      0.001      -0.118      -0.033
# MiscVal        -1.41e-06   7.72e-06     -0.183      0.855   -1.65e-05    1.37e-05
# MoSold            0.0009      0.001      0.619      0.536      -0.002       0.004
# YrSold           -0.0062      0.003     -2.101      0.036      -0.012      -0.000
# ==============================================================================
# Omnibus:                      953.300   Durbin-Watson:                   1.950
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            38852.448
# Skew:                          -2.459   Prob(JB):                         0.00
# Kurtosis:                      27.789   Cond. No.                     1.30e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.92e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ### 2. categorical(dummies)

# %%
categorical_features = ['MSSubClass', 'MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'Foundation', 'BsmtExposure', 'Heating', 'CentralAir', 'Electrical', 'Functional', 'GarageType', 'GarageFinish', 'PavedDrive', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']
train_c = pd.get_dummies(train[categorical_features])
train_c.tail()
# Out:
#       MSSubClass_120  MSSubClass_160  MSSubClass_180  MSSubClass_190  \
# 1455               0               0               0               0
# 1456               0               0               0               0
# 1457               0               0               0               0
# 1458               0               0               0               0
# 1459               0               0               0               0
#
#       MSSubClass_20  MSSubClass_30  MSSubClass_40  MSSubClass_45  \
# 1455              0              0              0              0
# 1456              1              0              0              0
# 1457              0              0              0              0
# 1458              1              0              0              0
# 1459              1              0              0              0
#
#       MSSubClass_50  MSSubClass_60          ...            SaleType_ConLw  \
# 1455              0              1          ...                         0
# 1456              0              0          ...                         0
# 1457              0              0          ...                         0
# 1458              0              0          ...                         0
# 1459              0              0          ...                         0
#
#       SaleType_New  SaleType_Oth  SaleType_WD  SaleCondition_Abnorml  \
# 1455             0             0            1                      0
# 1456             0             0            1                      0
# 1457             0             0            1                      0
# 1458             0             0            1                      0
# 1459             0             0            1                      0
#
#       SaleCondition_AdjLand  SaleCondition_Alloca  SaleCondition_Family  \
# 1455                      0                     0                     0
# 1456                      0                     0                     0
# 1457                      0                     0                     0
# 1458                      0                     0                     0
# 1459                      0                     0                     0
#
#       SaleCondition_Normal  SaleCondition_Partial
# 1455                     1                      0
# 1456                     1                      0
# 1457                     1                      0
# 1458                     1                      0
# 1459                     1                      0
#
# [5 rows x 217 columns]

# %%
model_2 = sm.OLS(y_train_l, train_c)
result_2 = model_2.fit()
print(result_2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.832
# Model:                            OLS   Adj. R-squared:                  0.808
# Method:                 Least Squares   F-statistic:                     34.75
# Date:                Mon, 12 Mar 2018   Prob (F-statistic):               0.00
# Time:                        23:37:56   Log-Likelihood:                 570.81
# No. Observations:                1460   AIC:                            -775.6
# Df Residuals:                    1277   BIC:                             191.7
# Df Model:                         182
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
#
# SaleType_New              0.3114      0.101      3.094      0.002       0.114       0.509
# SaleType_Oth              0.0705      0.098      0.716      0.474      -0.123       0.264
# SaleType_WD               0.1419      0.030      4.690      0.000       0.083       0.201
# SaleCondition_Abnorml     0.2847      0.033      8.644      0.000       0.220       0.349
# SaleCondition_AdjLand     0.2693      0.090      2.992      0.003       0.093       0.446
# SaleCondition_Alloca      0.3718      0.056      6.631      0.000       0.262       0.482
# SaleCondition_Family      0.2432      0.045      5.446      0.000       0.156       0.331
# SaleCondition_Normal      0.3325      0.029     11.489      0.000       0.276       0.389
# SaleCondition_Partial     0.2255      0.094      2.391      0.017       0.041       0.411
# ==============================================================================
# Omnibus:                       48.508   Durbin-Watson:                   1.950
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              126.828
# Skew:                           0.028   Prob(JB):                     2.88e-28
# Kurtosis:                       4.443   Cond. No.                     2.64e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.39e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ### 3. numerical + categorical(dummies)

# %%
train_all = pd.concat([train_n, train_c], axis=1)
train_all.tail()
# Out:
#       const  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 1455    1.0         62.0   7917.0          6.0          5.0     1999.0
# 1456    1.0         85.0  13175.0          6.0          6.0     1978.0
# 1457    1.0         66.0   9042.0          7.0          9.0     1941.0
# 1458    1.0         68.0   9717.0          5.0          6.0     1950.0
# 1459    1.0         75.0   9937.0          5.0          6.0     1965.0
#
#       YearRemodAdd  MasVnrArea  ExterQual  ExterCond          ...            \
# 1455        2000.0         0.0        6.0        6.0          ...
# 1456        1988.0       119.0        6.0        6.0          ...
# 1457        2006.0         0.0       10.0        8.0          ...
# 1458        1996.0         0.0        6.0        6.0          ...
# 1459        1965.0         0.0        8.0        6.0          ...
#
#       SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# 1455               0             0             0            1
# 1456               0             0             0            1
# 1457               0             0             0            1
# 1458               0             0             0            1
# 1459               0             0             0            1
#
#       SaleCondition_Abnorml  SaleCondition_AdjLand  SaleCondition_Alloca  \
# 1455                      0                      0                     0
# 1456                      0                      0                     0
# 1457                      0                      0                     0
# 1458                      0                      0                     0
# 1459                      0                      0                     0
#
#       SaleCondition_Family  SaleCondition_Normal  SaleCondition_Partial
# 1455                     0                     1                      0
# 1456                     0                     1                      0
# 1457                     0                     1                      0
# 1458                     0                     1                      0
# 1459                     0                     1                      0
#
# [5 rows x 265 columns]

# %%
model_3 = sm.OLS(y_train_l, train_all)
result_3 = model_3.fit()
print(result_3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.943
# Model:                            OLS   Adj. R-squared:                  0.932
# Method:                 Least Squares   F-statistic:                     89.21
# Date:                Mon, 12 Mar 2018   Prob (F-statistic):               0.00
# Time:                        23:38:15   Log-Likelihood:                 1355.4
# No. Observations:                1460   AIC:                            -2255.
# Df Residuals:                    1232   BIC:                            -1050.
# Df Model:                         227
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     1.2863      0.611      2.106      0.035       0.088       2.484
# LotFrontage               0.0004      0.000      1.835      0.067   -2.58e-05       0.001
# LotArea                2.443e-06   4.82e-07      5.065      0.000     1.5e-06    3.39e-06
# OverallQual               0.0407      0.005      8.791      0.000       0.032       0.050
# OverallCond               0.0348      0.004      8.858      0.000       0.027       0.043
# YearBuilt                 0.0018      0.000      4.667      0.000       0.001       0.002
# YearRemodAdd              0.0006      0.000      2.409      0.016       0.000       0.001
# MasVnrArea             3.039e-05   2.62e-05      1.160      0.246    -2.1e-05    8.18e-05
# ExterQual                -0.0006      0.005     -0.126      0.900      -0.010       0.009
# ExterCond                -0.0061      0.005     -1.261      0.208      -0.016       0.003
# BsmtQual                  0.0041      0.004      0.986      0.324      -0.004       0.012
# BsmtCond                  0.0030      0.006      0.532      0.595      -0.008       0.014
# BsmtFinType1              0.0019      0.001      1.666      0.096      -0.000       0.004
# BsmtFinSF1             5.294e-05   1.24e-05      4.275      0.000    2.86e-05    7.72e-05
# BsmtFinType2             -0.0013      0.003     -0.436      0.663      -0.007       0.004
# BsmtFinSF2             2.945e-05   2.42e-05      1.215      0.224   -1.81e-05     7.7e-05
Durbin-Watson:                   1.929
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4690.951
# Skew:                          -0.829   Prob(JB):                         0.00
# Kurtosis:                      11.623   Cond. No.                     1.53e+18
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.38e-25. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ### 4. numerical(correlation top 25)

# %%
cor_numerical_cols = ['OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
       'TotalBsmtSF', '1stFlrSF', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt',
       'YearRemodAdd', 'MasVnrArea', 'Fireplaces', 'BsmtFinSF1', 'LotFrontage',
       'WoodDeckSF', '2ndFlrSF', 'OpenPorchSF', 'HalfBath', 'LotArea',
       'GarageYrBlt', 'BsmtFullBath', 'BsmtUnfSF', 'BedroomAbvGr',
       'ScreenPorch']

train_nc = train[cor_numerical_cols]
train_nc.tail()
# Out:
#       OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF  1stFlrSF  \
# 1455            6       1647         2.0       460.0        953.0       953
# 1456            6       2073         2.0       500.0       1542.0      2073
# 1457            7       2340         1.0       252.0       1152.0      1188
# 1458            5       1078         1.0       240.0       1078.0      1078
# 1459            5       1256         1.0       276.0       1256.0      1256
#
#       FullBath  TotRmsAbvGrd  YearBuilt  YearRemodAdd     ...       \
# 1455         2             7       1999          2000     ...
# 1456         2             7       1978          1988     ...
# 1457         2             9       1941          2006     ...
# 1458         1             5       1950          1996     ...
# 1459         1             6       1965          1965     ...
#
#       WoodDeckSF  2ndFlrSF  OpenPorchSF  HalfBath  LotArea  GarageYrBlt  \
# 1455           0       694           40         1     7917       1999.0
# 1456         349         0            0         0    13175       1978.0
# 1457           0      1152           60         0     9042       1941.0
# 1458         366         0            0         0     9717       1950.0
# 1459         736         0           68         1     9937       1965.0
#
#       BsmtFullBath  BsmtUnfSF  BedroomAbvGr  ScreenPorch
# 1455           0.0      953.0             3            0
# 1456           1.0      589.0             3            0
# 1457           0.0      877.0             4            0
# 1458           1.0        0.0             2            0
# 1459           1.0      136.0             3            0
#
# [5 rows x 24 columns]

# %%
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(train_nc.values, i) for i in range(train_nc.values.shape[1])]
vif["features"] = train_nc.columns
vif.sort_values("VIF Factor", ascending = True)
# Out:
#      VIF Factor      features
# 23     1.156506   ScreenPorch
# 16     1.795103   OpenPorchSF
# 14     1.823784    WoodDeckSF
# 10     1.838063    MasVnrArea
# 18     2.640934       LotArea
# 11     2.891059    Fireplaces
# 17     3.156627      HalfBath
# 20     3.271262  BsmtFullBath
# 13    15.534835   LotFrontage
# 12    17.897683    BsmtFinSF1
# 6     21.735447      FullBath
# 21    23.405238     BsmtUnfSF
# 22    29.533380  BedroomAbvGr
# 3     31.249758    GarageArea
# 19    31.448751   GarageYrBlt
# 2     38.507625    GarageCars
# 0     54.203142   OverallQual
# 7     75.948405  TotRmsAbvGrd
# 4     77.150456   TotalBsmtSF
# 15   147.391152      2ndFlrSF
# 5    722.001919      1stFlrSF
# 1   1179.056549     GrLivArea
# 9   9141.706804  YearRemodAdd
# 8   9391.476875     YearBuilt

# %%
cor_numerical_cols = ['OverallQual', 'GrLivArea', 'GarageCars',
       'TotalBsmtSF', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt', 'MasVnrArea', 'Fireplaces', 'LotFrontage',
       'WoodDeckSF', 'OpenPorchSF', 'HalfBath', 'LotArea',
       'GarageYrBlt', 'BsmtFullBath',
       'ScreenPorch']

train_nc = train[cor_numerical_cols]
train_nc.tail()
# Out:
#       OverallQual  GrLivArea  GarageCars  TotalBsmtSF  FullBath  TotRmsAbvGrd  \
# 1455            6       1647         2.0        953.0         2             7
# 1456            6       2073         2.0       1542.0         2             7
# 1457            7       2340         1.0       1152.0         2             9
# 1458            5       1078         1.0       1078.0         1             5
# 1459            5       1256         1.0       1256.0         1             6
#
#       YearBuilt  MasVnrArea  Fireplaces  LotFrontage  WoodDeckSF  OpenPorchSF  \
# 1455       1999         0.0           1         62.0           0           40
# 1456       1978       119.0           2         85.0         349            0
# 1457       1941         0.0           2         66.0           0           60
# 1458       1950         0.0           0         68.0         366            0
# 1459       1965         0.0           0         75.0         736           68
#
#       HalfBath  LotArea  GarageYrBlt  BsmtFullBath  ScreenPorch
# 1455         1     7917       1999.0           0.0            0
# 1456         0    13175       1978.0           1.0            0
# 1457         0     9042       1941.0           0.0            0
# 1458         0     9717       1950.0           1.0            0
# 1459         1     9937       1965.0           1.0            0

# %%
model_4 = sm.OLS(y_train_l, train_nc)
result_4 = model_4.fit()
print(result_4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 4.120e+05
# Date:                Mon, 12 Mar 2018   Prob (F-statistic):               0.00
# Time:                        19:19:17   Log-Likelihood:                 492.77
# No. Observations:                1460   AIC:                            -951.5
# Df Residuals:                    1443   BIC:                            -861.7
# Df Model:                          17
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# OverallQual      0.0841      0.005     16.183      0.000       0.074       0.094
# GrLivArea        0.0003   2.06e-05     12.306      0.000       0.000       0.000
# GarageCars       0.0300      0.010      3.045      0.002       0.011       0.049
# TotalBsmtSF   3.116e-05   1.49e-05      2.091      0.037    1.93e-06    6.04e-05
# FullBath        -0.0547      0.012     -4.518      0.000      -0.078      -0.031
# TotRmsAbvGrd     0.0209      0.005      4.069      0.000       0.011       0.031
# YearBuilt        0.0055   1.82e-05    301.335      0.000       0.005       0.006
# MasVnrArea   -5.554e-05   2.89e-05     -1.925      0.054      -0.000    1.07e-06
# Fireplaces       0.0513      0.008      6.057      0.000       0.035       0.068
# LotFrontage      0.0003      0.000      1.126      0.260      -0.000       0.001
# WoodDeckSF       0.0001    3.9e-05      3.212      0.001    4.88e-05       0.000
# OpenPorchSF   1.844e-05   7.47e-05      0.247      0.805      -0.000       0.000
# HalfBath        -0.0472      0.011     -4.267      0.000      -0.069      -0.025
# LotArea       2.532e-06   5.08e-07      4.986      0.000    1.54e-06    3.53e-06
# GarageYrBlt   3.842e-05    1.3e-05      2.966      0.003     1.3e-05    6.38e-05
# BsmtFullBath     0.0492      0.010      5.122      0.000       0.030       0.068
# ScreenPorch      0.0005   8.41e-05      5.471      0.000       0.000       0.001
# ==============================================================================
# Omnibus:                      866.598   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            33478.161
# Skew:                          -2.142   Prob(JB):                         0.00
# Kurtosis:                      26.065   Cond. No.                     4.38e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.38e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### 5. numerical + categorical(correlation top 15,5)

# %%
cor_categorical_cols = ['Neighborhood', 'ExterQual', 'KitchenQual',
       'BsmtQual', 'PoolQC']

train_cc = train[cor_categorical_cols]
train_cc.tail()

train_all_c = pd.concat([train_nc, train_cc], axis=1)
train_all_c.tail()
# Out:
#       OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF  1stFlrSF  \
# 1455            6       1647         2.0       460.0        953.0       953
# 1456            6       2073         2.0       500.0       1542.0      2073
# 1457            7       2340         1.0       252.0       1152.0      1188
# 1458            5       1078         1.0       240.0       1078.0      1078
# 1459            5       1256         1.0       276.0       1256.0      1256
#
#       FullBath  TotRmsAbvGrd  YearBuilt  YearRemodAdd  GarageYrBlt  \
# 1455         2             7       1999          2000       1999.0
# 1456         2             7       1978          1988       1978.0
# 1457         2             9       1941          2006       1941.0
# 1458         1             5       1950          1996       1950.0
# 1459         1             6       1965          1965       1965.0
#
#       MasVnrArea  Fireplaces  BsmtFinSF1 Neighborhood ExterQual KitchenQual  \
# 1455         0.0           1         0.0      Gilbert        TA          TA
# 1456       119.0           2       790.0       NWAmes        TA          TA
# 1457         0.0           2       275.0      Crawfor        Ex          Gd
# 1458         0.0           0        49.0        NAmes        TA          Gd
# 1459         0.0           0       830.0      Edwards        Gd          TA
#
#      BsmtQual PoolQC
# 1455       Gd   None
# 1456       Gd   None
# 1457       TA   None
# 1458       TA   None
# 1459       TA   None

# %%
train_all_c = sm.add_constant(train_all_c)
train_all_c = pd.get_dummies(train_all_c)

train_all_c.tail()
# Out:
#       const  OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF  \
# 1455    1.0            6       1647         2.0       460.0        953.0
# 1456    1.0            6       2073         2.0       500.0       1542.0
# 1457    1.0            7       2340         1.0       252.0       1152.0
# 1458    1.0            5       1078         1.0       240.0       1078.0
# 1459    1.0            5       1256         1.0       276.0       1256.0
#
#       1stFlrSF  FullBath  TotRmsAbvGrd  YearBuilt     ...       \
# 1455       953         2             7       1999     ...
# 1456      2073         2             7       1978     ...
# 1457      1188         2             9       1941     ...
# 1458      1078         1             5       1950     ...
# 1459      1256         1             6       1965     ...
#
#       KitchenQual_TA  BsmtQual_Ex  BsmtQual_Fa  BsmtQual_Gd  BsmtQual_None  \
# 1455               1            0            0            1              0
# 1456               1            0            0            1              0
# 1457               0            0            0            0              0
# 1458               0            0            0            0              0
# 1459               1            0            0            0              0
#
#       BsmtQual_TA  PoolQC_Ex  PoolQC_Fa  PoolQC_Gd  PoolQC_None
# 1455            0          0          0          0            1
# 1456            0          0          0          0            1
# 1457            1          0          0          0            1
# 1458            1          0          0          0            1
# 1459            1          0          0          0            1
#
# [5 rows x 57 columns]

# %%
model1_5 = sm.OLS(y_train_l, train_all_c)
result1_5 = model1_5.fit()
print(result1_5.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.872
# Model:                            OLS   Adj. R-squared:                  0.867
# Method:                 Least Squares   F-statistic:                     187.5
# Date:                Mon, 12 Mar 2018   Prob (F-statistic):               0.00
# Time:                        15:57:12   Log-Likelihood:                 767.38
# No. Observations:                1460   AIC:                            -1431.
# Df Residuals:                    1408   BIC:                            -1156.
# Df Model:                          51
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    2.5106      0.396      6.332      0.000       1.733       3.288
# OverallQual              0.0674      0.005     12.348      0.000       0.057       0.078
# GrLivArea                0.0002   1.88e-05      8.631      0.000       0.000       0.000
# GarageCars               0.0368      0.013      2.818      0.005       0.011       0.062
# GarageArea            7.794e-05   4.27e-05      1.825      0.068   -5.83e-06       0.000
# TotalBsmtSF           1.141e-05    2.3e-05      0.497      0.620   -3.37e-05    5.65e-05
# 1stFlrSF              4.262e-05   2.43e-05      1.752      0.080   -5.09e-06    9.03e-05
# FullBath                 0.0138      0.011      1.223      0.222      -0.008       0.036
# TotRmsAbvGrd             0.0142      0.005      3.079      0.002       0.005       0.023
# YearBuilt                0.0010      0.000      3.096      0.002       0.000       0.002
# YearRemodAdd             0.0019      0.000      6.806      0.000       0.001       0.002
# GarageYrBlt           2.647e-05   1.17e-05      2.264      0.024    3.54e-06    4.94e-05
# MasVnrArea           -2.018e-05   2.72e-05     -0.743      0.457   -7.35e-05    3.31e-05
# Fireplaces               0.0513      0.008      6.777      0.000       0.036       0.066
Durbin-Watson:                   1.949
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            15096.496
# Skew:                          -1.771   Prob(JB):                         0.00
# Kurtosis:                      18.350   Cond. No.                     1.26e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.55e-22. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(train_all_c.values, i) for i in range(train_all_c.values.shape[1])]
vif["features"] = train_all_c.columns
vif
# Out:
#     VIF Factor              features
# 0     0.000000                 const
# 1     3.923020           OverallQual
# 2     6.713399             GrLivArea
# 3     6.552045            GarageCars
# 4     5.732055            GarageArea
# 5     6.989393           TotalBsmtSF
# 6     6.077954              1stFlrSF
# 7     2.641831              FullBath
# 8     3.883378          TotRmsAbvGrd
# 9     6.738343             YearBuilt
# 10    2.316177          YearRemodAdd
# 11    1.934078           GarageYrBlt
# 12    1.656497            MasVnrArea
# 13    1.634796            Fireplaces
# 14    1.677789            BsmtFinSF1
# 15         inf  Neighborhood_Blmngtn
# 16         inf  Neighborhood_Blueste
# 17         inf   Neighborhood_BrDale
# 18         inf  Neighborhood_BrkSide
# 19         inf  Neighborhood_ClearCr
# 20         inf  Neighborhood_CollgCr
# 21         inf  Neighborhood_Crawfor
# 22         inf  Neighborhood_Edwards
# 23         inf  Neighborhood_Gilbert
# 24         inf   Neighborhood_IDOTRR
# 25         inf  Neighborhood_MeadowV
# 26         inf  Neighborhood_Mitchel
# 27         inf    Neighborhood_NAmes
# 28         inf  Neighborhood_NPkVill
# 29         inf   Neighborhood_NWAmes
# 30         inf  Neighborhood_NoRidge
# 31         inf  Neighborhood_NridgHt
# 32         inf  Neighborhood_OldTown
# 33         inf    Neighborhood_SWISU
# 34         inf   Neighborhood_Sawyer
# 35         inf  Neighborhood_SawyerW
# 36         inf  Neighborhood_Somerst
# 37         inf  Neighborhood_StoneBr
# 38         inf   Neighborhood_Timber
# 39         inf  Neighborhood_Veenker
# 40         inf          ExterQual_Ex
# 41         inf          ExterQual_Fa
# 42         inf          ExterQual_Gd
# 43         inf          ExterQual_TA
# 44         inf        KitchenQual_Ex
# 45         inf        KitchenQual_Fa
# 46         inf        KitchenQual_Gd
# 47         inf        KitchenQual_TA
# 48         inf           BsmtQual_Ex
# 49         inf           BsmtQual_Fa
# 50         inf           BsmtQual_Gd
# 51         inf         BsmtQual_None
# 52         inf           BsmtQual_TA
# 53         inf             PoolQC_Ex
# 54         inf             PoolQC_Fa
# 55         inf             PoolQC_Gd
# 56         inf           PoolQC_None

# %%
model_cat = sm.OLS.from_formula("SalePrice ~ C(Neighborhood)", data=train)
sm.stats.anova_lm(model_cat.fit())
# Out:
#                      df        sum_sq       mean_sq          F         PR(>F)
# C(Neighborhood)    24.0  5.023606e+12  2.093169e+11  71.784865  1.558600e-225
# Residual         1435.0  4.184305e+12  2.915892e+09        NaN            NaN

# %%
model_cat = sm.OLS.from_formula("SalePrice ~ C(ExterQual)", data=train)
sm.stats.anova_lm(model_cat.fit())
# Out:
#                   df        sum_sq       mean_sq           F         PR(>F)
# C(ExterQual)     3.0  4.395744e+12  1.465248e+12  443.334831  1.439551e-204
# Residual      1456.0  4.812167e+12  3.305060e+09         NaN            NaN

# %%
model_cat = sm.OLS.from_formula("SalePrice ~ C(KitchenQual)", data=train)
sm.stats.anova_lm(model_cat.fit())
# Out:
#                     df        sum_sq       mean_sq           F         PR(>F)
# C(KitchenQual)     3.0  4.204320e+12  1.401440e+12  407.806352  3.032213e-192
# Residual        1456.0  5.003592e+12  3.436533e+09         NaN            NaN

# %%
model_cat = sm.OLS.from_formula("SalePrice ~ C(BsmtQual)", data=train)
sm.stats.anova_lm(model_cat.fit())
# Out:
#                  df        sum_sq       mean_sq           F         PR(>F)
# C(BsmtQual)     4.0  4.281621e+12  1.070405e+12  316.148635  8.158548e-196
# Residual     1455.0  4.926290e+12  3.385766e+09         NaN            NaN

# %%
model_cat = sm.OLS.from_formula("SalePrice ~ C(PoolQC)", data=train)
sm.stats.anova_lm(model_cat.fit())
# Out:
#                df        sum_sq       mean_sq          F        PR(>F)
# C(PoolQC)     3.0  1.951702e+11  6.505672e+10  10.509853  7.700989e-07
# Residual   1456.0  9.012741e+12  6.190069e+09        NaN           NaN

# %% [markdown]
# #### 성능 비교

# %%
# adj r^2
print(result1_1.rsquared_adj)
print(result1_2.rsquared_adj)
print(result1_3.rsquared_adj)
print(result1_4.rsquared_adj)
print(result1_5.rsquared_adj)
# Out:
# 0.9998476791817901
# 0.8616798648653539
# 0.9332264620894861
# 0.9998167761418959
# 0.867010499542905

# %%
#AIC
print(result1_1.aic)
print(result1_2.aic)
print(result1_3.aic)
print(result1_4.aic)
print(result1_5.aic)
# Out:
# -1393.3948796096452
# -1214.7173163945513
# -2251.688475707486
# -1142.3929660338258
# -1430.7683576721279

# %%
#BIC
print(result1_1.bic)
print(result1_2.bic)
print(result1_3.bic)
print(result1_4.bic)
print(result1_5.bic)
# Out:
# -1218.9505530244664
# 1.1067779869965761
# -861.4200547407593
# -1068.3862820279924
# -1155.886388507604

# %% [markdown]
# - adj r^2 : 모델 1, 4 거의 비슷
# - AIC : 모델 1, 5 거의 비슷
# - BIC : 모델 1, 5 거의 비슷

# %% [markdown]
# #### partial regression plot & CCPR

# %%
# fig = plt.figure(figsize=(8,30))
# sm.graphics.plot_partregress_grid(result1_1, fig=fig)
# fig.suptitle("")
# plt.show

# %%
# fig = plt.figure(figsize=(15,40))
# sm.graphics.plot_ccpr_grid(result1_1, fig=fig)
# fig.suptitle("")
# plt.show

# %% [markdown]
# ## Outliers

# %%
influence = result1_1.get_influence()
# hat = influence.hat_matrix_diag

# plt.figure(figsize=(15,6))
# plt.stem(hat)
# plt.show()

# %%
# hat.sum()

# %%
# plt.figure(figsize=(15, 6))
# plt.stem(result1_1.resid_pearson)
# plt.show()

# %%
# g = sm.graphics.plot_leverage_resid2(result1_1)
# g.set_size_inches(15,5)
# plt.show()

# %%
o_train = train[result1_1.resid_pearson > 2]
print(len(o_train))
idx_r = np.where(result1_1.resid_pearson > 2)[0]
print(idx_r)
# Out:
# 26
# [  48  142  151  178  181  218  277  378  457  473  546  669  681  688
#   803  807  898  970 1046 1059 1065 1075 1170 1181 1182 1423]

# %%
cooks_d2, pvals = influence.cooks_distance
fox_cr = 4 / (len(y_train_l) - len(train_n.columns) - 1)
idx_c = np.where(cooks_d2 > fox_cr)[0]

ax = plt.subplot()
plt.scatter(train['GrLivArea'], y_train_d)
plt.scatter(train['GrLivArea'][idx_c], y_train_d[idx_c], s=100, c="r", alpha=0.3)
utils.annotate_axes(range(len(idx_c)), idx_c, 
                    list(zip(train['GrLivArea'][idx_c], y_train_d[idx_c])), [(-20, 15)] * len(idx_c), size="small", ax=ax)
plt.show()

print(len(idx_c),idx_c)
# Out:
# 67 [  30   48   88   93  125  144  153  178  197  205  218  277  335  346
#   375  378  410  431  457  462  495  523  546  588  608  628  632  635
#   658  662  664  666  691  705  710  728  738  803  807  810  812  898
#   907  916  942  968  970 1030 1048 1059 1062 1068 1080 1170 1181 1182
#  1211 1216 1298 1324 1337 1386 1415 1423 1432 1437 1453]

# %%
resid_outliers = idx_r.tolist()
cooks_outliers = idx_c.tolist()
print("resid_outliers:", len(resid_outliers), resid_outliers)
print("\t")
print("cooks_outliers:", len(cooks_outliers), cooks_outliers)
print("\t")
print("(IQR)GrLivArea_outliers:", len(GrLivArea_outliers), GrLivArea_outliers)
print("\t")
print("(IQR)OverallQual_outliers", len(OverallQual_outliers), OverallQual_outliers)
print("\t")
print("(IQR)GarageCars_outliers:", len(GarageCars_outliers), GarageCars_outliers)

#제거하길 추천한 outliers(data description)
recommended_outliers = [523, 898, 1298]
# Out:
# resid_outliers: 26 [48, 142, 151, 178, 181, 218, 277, 378, 457, 473, 546, 669, 681, 688, 803, 807, 898, 970, 1046, 1059, 1065, 1075, 1170, 1181, 1182, 1423]
#
# cooks_outliers: 67 [30, 48, 88, 93, 125, 144, 153, 178, 197, 205, 218, 277, 335, 346, 375, 378, 410, 431, 457, 462, 495, 523, 546, 588, 608, 628, 632, 635, 658, 662, 664, 666, 691, 705, 710, 728, 738, 803, 807, 810, 812, 898, 907, 916, 942, 968, 970, 1030, 1048, 1059, 1062, 1068, 1080, 1170, 1181, 1182, 1211, 1216, 1298, 1324, 1337, 1386, 1415, 1423, 1432, 1437, 1453]
#
# (IQR)GrLivArea_outliers: 31 [58, 118, 185, 197, 231, 304, 324, 496, 523, 583, 608, 635, 691, 769, 798, 803, 961, 1024, 1031, 1046, 1142, 1169, 1173, 1175, 1182, 1268, 1298, 1312, 1328, 1353, 1386]
#
# (IQR)OverallQual_outliers 2 [375, 533]
#
# (IQR)GarageCars_outliers: 21 [178, 224, 270, 317, 408, 581, 664, 718, 803, 825, 1061, 1087, 1142, 1184, 1190, 1228, 1241, 1268, 1298, 1350, 1417]

# %%
IQR = list(set(GrLivArea_outliers) | set(OverallQual_outliers) | set(GarageCars_outliers))
print(IQR)
# Out:
# [1024, 769, 1031, 1417, 523, 270, 1169, 1298, 1173, 1046, 1175, 533, 664, 408, 798, 1182, 1312, 1184, 803, 1061, 1190, 304, 1328, 178, 691, 185, 58, 825, 317, 1087, 961, 324, 197, 581, 583, 1350, 1353, 1228, 718, 1241, 608, 224, 231, 1386, 496, 1268, 118, 375, 1142, 635]

# %%
resid_cooks = list(set(resid_outliers) | set(cooks_outliers))
print(resid_cooks)
# Out:
# [1030, 523, 1298, 277, 1046, 1048, 30, 546, 803, 1059, 1062, 807, 1065, 810, 812, 1068, 1324, 48, 1075, 1080, 1337, 588, 335, 88, 346, 93, 608, 1386, 628, 375, 632, 378, 635, 125, 898, 1415, 907, 142, 1423, 144, 1170, 658, 916, 662, 151, 664, 153, 410, 666, 1432, 669, 1181, 1182, 1437, 681, 1453, 942, 431, 688, 178, 691, 181, 1211, 1216, 705, 197, 710, 968, 457, 970, 205, 462, 728, 473, 218, 738, 495]

# %%
IQR2 = list(set(GrLivArea_outliers) & set(GarageCars_outliers))
print(IQR2)
# Out:
# [1298, 803, 1268, 1142]

# %%
resid_cooks_IQR = list(set(resid_cooks) | set(IQR))
print(resid_cooks_IQR)
# Out:
# [1024, 769, 1030, 1031, 523, 270, 1298, 277, 1046, 533, 1048, 1175, 30, 798, 1312, 546, 803, 1059, 1061, 1062, 807, 1065, 810, 812, 1068, 1324, 48, 304, 1328, 1075, 1080, 1337, 58, 825, 317, 1087, 324, 581, 1350, 583, 1353, 588, 335, 88, 346, 93, 608, 1386, 628, 118, 375, 632, 1142, 378, 635, 125, 898, 1415, 1417, 907, 142, 1423, 144, 1169, 1170, 658, 916, 1173, 662, 151, 664, 153, 410, 666, 1432, 669, 1181, 1182, 1437, 408, 1184, 1190, 681, 1453, 942, 431, 688, 178, 691, 181, 185, 1211, 1216, 705, 961, 197, 710, 968, 457, 970, 1228, 205, 462, 718, 728, 473, 218, 1241, 224, 738, 231, 495, 496, 1268]

# %% [markdown]
# ## Select Variables

# %%
idx_t = np.where(result1_1.pvalues < 0.05)[0]
print(len(idx_t), idx_t)
tvalues = idx_t.tolist()
# Out:
# 20 [ 1  2  3  4  5  7 10 11 14 15 17 20 21 22 24 26 28 30 31 34]

# %%
x_train_cols = train_n.columns.tolist()
print(len(x_train_cols))

select = []

for i in tvalues:
    select.append(x_train_cols[i])

print(len(select), select)
# Out:
# 35
# 20 ['LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'BsmtFinSF1', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'BsmtFullBath', 'FullBath', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars', 'WoodDeckSF', 'EnclosedPorch', 'ScreenPorch', 'PoolArea', 'YrSold']

# %%
idx_t2 = np.where(result1_3.pvalues < 0.005)[0]
print(len(idx_t2), idx_t2)
tvalues2 = idx_t2.tolist()

x_train_cols2 = train_all.columns.tolist()
print(len(x_train_cols2))

select_c = []

for i in tvalues2:
    select_c.append(x_train_cols2[i])

print(len(select_c), select_c)

select_c = ['MSZoning', 'Neighborhood', 'Condition2', 'RoofMatl', 'Functional']
# Out:
# 40 [  1   2   3   4   5   7  10  14  25  26  30  51  52  53  82  92  98 111
#  112 113 114 117 124 136 137 138 139 140 142 143 144 148 226 246 248 249
#  252 270 280 302]
# 314
# 40 ['LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'BsmtFinSF1', 'TotalBsmtSF', 'GrLivArea', 'GarageArea', 'WoodDeckSF', 'ScreenPorch', 'MSZoning_FV', 'MSZoning_RH', 'MSZoning_RL', 'Neighborhood_Crawfor', 'Neighborhood_NridgHt', 'Neighborhood_StoneBr', 'Condition2_Feedr', 'Condition2_Norm', 'Condition2_PosA', 'Condition2_PosN', 'Condition2_RRNn', 'HouseStyle_1.5Unf', 'RoofStyle_Shed', 'RoofMatl_ClyTile', 'RoofMatl_CompShg', 'RoofMatl_Membran', 'RoofMatl_Metal', 'RoofMatl_Tar&Grv', 'RoofMatl_WdShake', 'RoofMatl_WdShngl', 'Exterior1st_BrkFace', 'Heating_GasW', 'Functional_Maj1', 'Functional_Min1', 'Functional_Min2', 'Functional_Typ', 'GarageQual_Ex', 'GarageCond_Po', 'SaleType_ConLD']

# %%
x_train_new = train_n[select]

vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(x_train_new.values, i) for i in range(x_train_new.values.shape[1])]
vif["features"] = x_train_new.columns
vif.sort_values(by="VIF Factor", ascending=True)
# Out:
#       VIF Factor       features
# 18      1.070626       PoolArea
# 17      1.170613    ScreenPorch
# 16      1.426199  EnclosedPorch
# 15      1.851504     WoodDeckSF
# 0       2.524493        LotArea
# 13      2.867944     Fireplaces
# 9       3.079493   BsmtFullBath
# 5       4.488814     BsmtFinSF1
# 14     12.509448     GarageCars
# 10     21.737438       FullBath
# 6      26.799596    TotalBsmtSF
# 11     31.900475   KitchenAbvGr
# 7      38.927028       1stFlrSF
# 2      39.291508    OverallCond
# 8      52.111278      GrLivArea
# 1      62.453104    OverallQual
# 12     63.183161   TotRmsAbvGrd
# 3   15116.215362      YearBuilt
# 4   19639.630854   YearRemodAdd
# 19  19829.680597         YrSold

# %% [markdown]
# - Yearsold, YearRemodAdd, TotRmsAbvGrd, OverallQual 제외
#
# - ** OverrallCond, 1stFlrSF, KitchenAbvGr, PoolArea, Screenporch(from_formula 사용시)

# %%
select = ['LotArea', 'OverallCond', 'YearBuilt', 'BsmtFinSF1', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'BsmtFullBath', 'FullBath', 'KitchenAbvGr', 'Fireplaces', 'GarageCars', 'WoodDeckSF', 'EnclosedPorch', 'ScreenPorch', 'PoolArea']
print(len(select), select)

x_train_new = x_train_new[select]
# Out:
# 16 ['LotArea', 'OverallCond', 'YearBuilt', 'BsmtFinSF1', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'BsmtFullBath', 'FullBath', 'KitchenAbvGr', 'Fireplaces', 'GarageCars', 'WoodDeckSF', 'EnclosedPorch', 'ScreenPorch', 'PoolArea']

# %% [markdown]
# - 참고 : 상관계수와 coef?

# %%
print(len(cor_numerical_cols),cor_numerical_cols)
print("\t")

cols_common = set(select) & set(cor_numerical_cols)
cols_sum = set(select) | set(cor_numerical_cols)

print(len(cols_common), cols_common)
print("\t")
print(len(cols_sum), cols_sum)
# Out:
# 14 ['OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea', 'TotalBsmtSF', '1stFlrSF', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'MasVnrArea', 'Fireplaces', 'BsmtFinSF1']
#
# 8 {'FullBath', '1stFlrSF', 'TotalBsmtSF', 'GarageCars', 'Fireplaces', 'GrLivArea', 'YearBuilt', 'BsmtFinSF1'}
#
# 22 {'FullBath', '1stFlrSF', 'WoodDeckSF', 'TotalBsmtSF', 'ScreenPorch', 'GarageCars', 'Fireplaces', 'MasVnrArea', 'PoolArea', 'YearBuilt', 'TotRmsAbvGrd', 'LotArea', 'OverallCond', 'GarageArea', 'OverallQual', 'GarageYrBlt', 'YearRemodAdd', 'GrLivArea', 'BsmtFullBath', 'EnclosedPorch', 'KitchenAbvGr', 'BsmtFinSF1'}

# %%
select = ['EnclosedPorch', '1stFlrSF', 'BsmtFinSF1', 'GarageCars', 'YearRemodAdd', 'BsmtFullBath', 'MasVnrArea', 'Fireplaces', 'TotalBsmtSF', 'PoolArea', 'OverallCond', 'ScreenPorch', 'WoodDeckSF', 'LotArea', 'YearBuilt', 'GarageArea', 'GrLivArea', 'KitchenAbvGr', 'TotRmsAbvGrd', 'FullBath', 'GarageYrBlt', 'OverallQual']
len(select)
# Out:
# 22

# %%
select_VIF = ['MasVnrArea', 'EnclosedPorch', 'BsmtFinSF1', 'GarageCars', 'BsmtFullBath', 'Fireplaces', 'TotalBsmtSF', 'ScreenPorch', 'WoodDeckSF', 'LotArea', 'YearBuilt', 'GrLivArea', 'KitchenAbvGr', 'FullBath', 'OverallQual', 'OverallCond']

# %%
x_train_new = train_n[select_VIF]

vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(x_train_new.values, i) for i in range(x_train_new.values.shape[1])]
vif["features"] = x_train_new.columns
vif.sort_values(by="VIF Factor", ascending=True)
# Out:
#     VIF Factor       features
# 7     1.155940    ScreenPorch
# 1     1.225614  EnclosedPorch
# 0     1.769256     MasVnrArea
# 8     1.838235     WoodDeckSF
# 9     2.498450        LotArea
# 5     2.770257     Fireplaces
# 4     3.054476   BsmtFullBath
# 2     4.407584     BsmtFinSF1
# 3    11.641829     GarageCars
# 6    13.632549    TotalBsmtSF
# 13   18.917270       FullBath
# 11   23.914219      GrLivArea
# 12   27.599095   KitchenAbvGr
# 15   27.656807    OverallCond
# 14   54.458837    OverallQual
# 10   94.201578      YearBuilt

# %% [markdown]
# ## Second OLS

# %%
train_cc = train[cor_categorical_cols]

# %%
#추가 작업
train_cc = train_cc.drop(['PoolQC'], axis=1)

train_cc = train_cc.drop(resid_cooks)
train_n = train_n[select_VIF]
train_n = train_n.drop(resid_cooks)
#추가 작업-변수 변환 
train_n = np.log1p(train_n)
x_train_new = train_n
x_train_new = pd.concat([train_n, train_cc], axis=1)
#add constatns
# x_train_new = sm.add_constant(x_train_new)

y_train_new = y_train_d.drop(resid_cooks)
y_train_new = np.log1p(y_train_new)

# #from_formula 사용 위해
train_new = pd.concat([y_train_new, x_train_new], axis=1)
train_new.tail()
# Out:
#       SalePrice  MasVnrArea  EnclosedPorch  BsmtFinSF1  GarageCars  \
# 1455  12.072547    0.000000       0.000000    0.000000    1.098612
# 1456  12.254868    4.787492       0.000000    6.673298    1.098612
# 1457  12.493133    0.000000       0.000000    5.620401    0.693147
# 1458  11.864469    0.000000       4.727388    3.912023    0.693147
# 1459  11.901590    0.000000       0.000000    6.722630    0.693147
#
#       BsmtFullBath  Fireplaces  TotalBsmtSF  ScreenPorch  WoodDeckSF   ...     \
# 1455      0.000000    0.693147     6.860664          0.0    0.000000   ...
# 1456      0.693147    1.098612     7.341484          0.0    5.857933   ...
# 1457      0.000000    1.098612     7.050123          0.0    0.000000   ...
# 1458      0.693147    0.000000     6.983790          0.0    5.905362   ...
# 1459      0.693147    0.000000     7.136483          0.0    6.602588   ...
#
#       YearBuilt  GrLivArea  KitchenAbvGr  FullBath  OverallQual  OverallCond  \
# 1455   7.600902   7.407318      0.693147  1.098612     1.945910     1.791759
# 1456   7.590347   7.637234      0.693147  1.098612     1.945910     1.945910
# 1457   7.571474   7.758333      0.693147  1.098612     2.079442     2.302585
# 1458   7.576097   6.983790      0.693147  0.693147     1.791759     1.945910
# 1459   7.583756   7.136483      0.693147  0.693147     1.791759     1.945910
#
#       Neighborhood ExterQual KitchenQual BsmtQual
# 1455       Gilbert        TA          TA       Gd
# 1456        NWAmes        TA          TA       Gd
# 1457       Crawfor        Ex          Gd       TA
# 1458         NAmes        TA          Gd       TA
# 1459       Edwards        Gd          TA       TA
#
# [5 rows x 21 columns]

# %%
select_scale = []

for num in select_VIF:
    x = "scale(" + num + ")"
    select_scale.append(x)

print(select_scale)

formula = " + ".join(select_scale)
formula
# Out:
# ['scale(MasVnrArea)', 'scale(EnclosedPorch)', 'scale(BsmtFinSF1)', 'scale(GarageCars)', 'scale(BsmtFullBath)', 'scale(Fireplaces)', 'scale(TotalBsmtSF)', 'scale(ScreenPorch)', 'scale(WoodDeckSF)', 'scale(LotArea)', 'scale(YearBuilt)', 'scale(GrLivArea)', 'scale(KitchenAbvGr)', 'scale(FullBath)', 'scale(OverallQual)', 'scale(OverallCond)']
# 'scale(MasVnrArea) + scale(EnclosedPorch) + scale(BsmtFinSF1) + scale(GarageCars) + scale(BsmtFullBath) + scale(Fireplaces) + scale(TotalBsmtSF) + scale(ScreenPorch) + scale(WoodDeckSF) + scale(LotArea) + scale(YearBuilt) + scale(GrLivArea) + scale(KitchenAbvGr) + scale(FullBath) + scale(OverallQual) + scale(OverallCond)'

# %%
train_cc.columns
# Out:
# Index(['Neighborhood', 'ExterQual', 'KitchenQual', 'BsmtQual'], dtype='object')

# %%
train_new.tail()
# Out:
#       SalePrice  MasVnrArea  EnclosedPorch  BsmtFinSF1  GarageCars  \
# 1455  12.072547    0.000000       0.000000    0.000000    1.098612
# 1456  12.254868    4.787492       0.000000    6.673298    1.098612
# 1457  12.493133    0.000000       0.000000    5.620401    0.693147
# 1458  11.864469    0.000000       4.727388    3.912023    0.693147
# 1459  11.901590    0.000000       0.000000    6.722630    0.693147
#
#       BsmtFullBath  Fireplaces  TotalBsmtSF  ScreenPorch  WoodDeckSF   ...     \
# 1455      0.000000    0.693147     6.860664          0.0    0.000000   ...
# 1456      0.693147    1.098612     7.341484          0.0    5.857933   ...
# 1457      0.000000    1.098612     7.050123          0.0    0.000000   ...
# 1458      0.693147    0.000000     6.983790          0.0    5.905362   ...
# 1459      0.693147    0.000000     7.136483          0.0    6.602588   ...
#
#       YearBuilt  GrLivArea  KitchenAbvGr  FullBath  OverallQual  OverallCond  \
# 1455   7.600902   7.407318      0.693147  1.098612     1.945910     1.791759
# 1456   7.590347   7.637234      0.693147  1.098612     1.945910     1.945910
# 1457   7.571474   7.758333      0.693147  1.098612     2.079442     2.302585
# 1458   7.576097   6.983790      0.693147  0.693147     1.791759     1.945910
# 1459   7.583756   7.136483      0.693147  0.693147     1.791759     1.945910
#
#       Neighborhood ExterQual KitchenQual BsmtQual
# 1455       Gilbert        TA          TA       Gd
# 1456        NWAmes        TA          TA       Gd
# 1457       Crawfor        Ex          Gd       TA
# 1458         NAmes        TA          Gd       TA
# 1459       Edwards        Gd          TA       TA
#
# [5 rows x 21 columns]

# %%
# train_new = train_new.drop(['1stFlrSF'], axis=1)
train_new.tail()
# Out:
#       SalePrice  MasVnrArea  EnclosedPorch  BsmtFinSF1  GarageCars  \
# 1455  12.072547    0.000000       0.000000    0.000000    1.098612
# 1456  12.254868    4.787492       0.000000    6.673298    1.098612
# 1457  12.493133    0.000000       0.000000    5.620401    0.693147
# 1458  11.864469    0.000000       4.727388    3.912023    0.693147
# 1459  11.901590    0.000000       0.000000    6.722630    0.693147
#
#       BsmtFullBath  Fireplaces  TotalBsmtSF  ScreenPorch  WoodDeckSF   ...     \
# 1455      0.000000    0.693147     6.860664          0.0    0.000000   ...
# 1456      0.693147    1.098612     7.341484          0.0    5.857933   ...
# 1457      0.000000    1.098612     7.050123          0.0    0.000000   ...
# 1458      0.693147    0.000000     6.983790          0.0    5.905362   ...
# 1459      0.693147    0.000000     7.136483          0.0    6.602588   ...
#
#       YearBuilt  GrLivArea  KitchenAbvGr  FullBath  OverallQual  OverallCond  \
# 1455   7.600902   7.407318      0.693147  1.098612     1.945910     1.791759
# 1456   7.590347   7.637234      0.693147  1.098612     1.945910     1.945910
# 1457   7.571474   7.758333      0.693147  1.098612     2.079442     2.302585
# 1458   7.576097   6.983790      0.693147  0.693147     1.791759     1.945910
# 1459   7.583756   7.136483      0.693147  0.693147     1.791759     1.945910
#
#       Neighborhood ExterQual KitchenQual BsmtQual
# 1455       Gilbert        TA          TA       Gd
# 1456        NWAmes        TA          TA       Gd
# 1457       Crawfor        Ex          Gd       TA
# 1458         NAmes        TA          Gd       TA
# 1459       Edwards        Gd          TA       TA
#
# [5 rows x 21 columns]

# %%
# x_train_new = pd.get_dummies(x_train_new)
# x_train_new.tail()

# %%
model2_1 = sm.OLS.from_formula("SalePrice ~ scale(MasVnrArea) + scale(EnclosedPorch) + scale(BsmtFinSF1) + scale(GarageCars) + scale(BsmtFullBath) + scale(Fireplaces) + scale(TotalBsmtSF) + scale(ScreenPorch) + scale(WoodDeckSF) + scale(LotArea) + scale(YearBuilt) + scale(GrLivArea) + scale(KitchenAbvGr) + scale(FullBath) + scale(OverallQual) + scale(OverallCond) + C(Neighborhood) + C(ExterQual) + C(KitchenQual) + C(BsmtQual)", data=train_new)
result2_1 = model2_1.fit()
print(result2_1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.943
# Model:                            OLS   Adj. R-squared:                  0.941
# Method:                 Least Squares   F-statistic:                     440.3
# Date:                Mon, 12 Mar 2018   Prob (F-statistic):               0.00
# Time:                        15:57:31   Log-Likelihood:                 1384.8
# No. Observations:                1383   AIC:                            -2668.
# Df Residuals:                    1332   BIC:                            -2401.
# Df Model:                          50
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     12.2667      0.031    394.349      0.000      12.206      12.328
# C(Neighborhood)[T.Blueste]    -0.0723      0.069     -1.044      0.297      -0.208       0.064
# C(Neighborhood)[T.BrDale]     -0.0955      0.035     -2.726      0.006      -0.164      -0.027
# C(Neighborhood)[T.BrkSide]    -0.0383      0.030     -1.278      0.201      -0.097       0.020
# C(Neighborhood)[T.ClearCr]    -0.0590      0.033     -1.794      0.073      -0.123       0.006
# C(Neighborhood)[T.CollgCr]    -0.0491      0.026     -1.910      0.056      -0.099       0.001
# C(Neighborhood)[T.Crawfor]     0.0226      0.030      0.748      0.455      -0.037       0.082
# C(Neighborhood)[T.Edwards]    -0.1256      0.028     -4.462      0.000      -0.181      -0.070
# C(Neighborhood)[T.Gilbert]    -0.0743      0.027     -2.721      0.007      -0.128      -0.021
# C(Neighborhood)[T.IDOTRR]     -0.0962      0.033     -2.957      0.003      -0.160      -0.032
# C(Neighborhood)[T.MeadowV]    -0.1019      0.034     -2.954      0.003      -0.170      -0.034
# C(Neighborhood)[T.Mitchel]    -0.1015      0.029     -3.484      0.001      -0.159      -0.044
# C(Neighborhood)[T.NAmes]      -0.0848      0.027     -3.118      0.002      -0.138      -0.031
# C(Neighborhood)[T.NPkVill]    -0.0624      0.039     -1.586      0.113      -0.140       0.015
# C(Neighborhood)[T.NWAmes]     -0.1142      0.028     -4.068      0.000      -0.169      -0.059
# C(Neighborhood)[T.NoRidge]     0.0375      0.029      1.283      0.200      -0.020       0.095
# C(Neighborhood)[T.NridgHt]     0.0100      0.027      0.369      0.712      -0.043       0.063
# C(Neighborhood)[T.OldTown]    -0.0812      0.029     -2.768      0.006      -0.139      -0.024
# C(Neighborhood)[T.SWISU]      -0.0823      0.034     -2.423      0.016      -0.149      -0.016
# C(Neighborhood)[T.Sawyer]     -0.0907      0.029     -3.167      0.002      -0.147      -0.034
# C(Neighborhood)[T.SawyerW]    -0.0872      0.028     -3.169      0.002      -0.141      -0.033
# C(Neighborhood)[T.Somerst]     0.0321      0.026      1.234      0.217      -0.019       0.083
# C(Neighborhood)[T.StoneBr]     0.0413      0.031      1.323      0.186      -0.020       0.102
# C(Neighborhood)[T.Timber]     -0.0565      0.029     -1.923      0.055      -0.114       0.001
# C(Neighborhood)[T.Veenker]    -0.0211      0.038     -0.562      0.574      -0.095       0.053
# C(ExterQual)[T.Fa]            -0.0617      0.038     -1.614      0.107      -0.137       0.013
# C(ExterQual)[T.Gd]            -0.0359      0.018     -1.985      0.047      -0.071      -0.000
# C(ExterQual)[T.TA]            -0.0492      0.020     -2.480      0.013      -0.088      -0.010
# C(KitchenQual)[T.Fa]          -0.0864      0.023     -3.771      0.000      -0.131      -0.041
# C(KitchenQual)[T.Gd]          -0.0778      0.013     -5.951      0.000      -0.103      -0.052
# C(KitchenQual)[T.TA]          -0.0994      0.014     -6.873      0.000      -0.128      -0.071
# C(BsmtQual)[T.Fa]             -0.0853      0.023     -3.654      0.000      -0.131      -0.039
# C(BsmtQual)[T.Gd]             -0.0764      0.012     -6.204      0.000      -0.101      -0.052
# C(BsmtQual)[T.None]            0.6417      0.071      9.053      0.000       0.503       0.781
# C(BsmtQual)[T.TA]             -0.0765      0.015     -5.148      0.000      -0.106      -0.047
# scale(MasVnrArea)              0.0010      0.003      0.317      0.751      -0.005       0.007
# scale(EnclosedPorch)           0.0041      0.003      1.428      0.154      -0.002       0.010
# scale(BsmtFinSF1)              0.0189      0.003      5.542      0.000       0.012       0.026
# scale(GarageCars)              0.0296      0.003      8.788      0.000       0.023       0.036
# scale(BsmtFullBath)            0.0198      0.003      6.026      0.000       0.013       0.026
# scale(Fireplaces)              0.0180      0.003      5.721      0.000       0.012       0.024
# scale(TotalBsmtSF)             0.1278      0.011     11.586      0.000       0.106       0.149
# scale(ScreenPorch)             0.0115      0.003      4.445      0.000       0.006       0.017
# scale(WoodDeckSF)              0.0119      0.003      4.333      0.000       0.006       0.017
# scale(LotArea)                 0.0567      0.004     14.909      0.000       0.049       0.064
# scale(YearBuilt)               0.0904      0.007     13.679      0.000       0.077       0.103
# scale(GrLivArea)               0.1258      0.004     28.984      0.000       0.117       0.134
# scale(KitchenAbvGr)           -0.0182      0.003     -6.370      0.000      -0.024      -0.013
# scale(FullBath)                0.0113      0.004      2.871      0.004       0.004       0.019
# scale(OverallQual)             0.0613      0.005     13.101      0.000       0.052       0.071
# scale(OverallCond)             0.0576      0.003     19.524      0.000       0.052       0.063
# ==============================================================================
# Omnibus:                       65.640   Durbin-Watson:                   1.961
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              146.769
# Skew:                          -0.281   Prob(JB):                     1.35e-32
# Kurtosis:                       4.494   Cond. No.                         110.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# - ANOVA

# %%
# #모형비교

# model_full = sm.OLS.from_formula("SalePrice ~ scale(EnclosedPorch) + scale(BsmtFinSF1) + scale(OverallCond) + scale(GarageCars) + scale(BsmtFullBath) + scale(MasVnrArea) + scale(Fireplaces) + scale(TotalBsmtSF) + scale(ScreenPorch) + scale(WoodDeckSF) + scale(LotArea) + scale(YearBuilt) + scale(GrLivArea) + scale(KitchenAbvGr) + scale(FullBath) + scale(OverallQual) + C(Neighborhood) + C(ExterQual) + C(KitchenQual) + C(BsmtQual)", data=train_new)
# model_reduced = sm.OLS.from_formula("SalePrice ~ scale(EnclosedPorch) + scale(BsmtFinSF1) + scale(OverallCond) + scale(GarageCars) + scale(BsmtFullBath) + scale(MasVnrArea) + scale(Fireplaces) + scale(TotalBsmtSF) + scale(ScreenPorch) + scale(WoodDeckSF) + scale(LotArea) + scale(YearBuilt) + scale(GrLivArea) + scale(KitchenAbvGr) + scale(FullBath) + scale(OverallQual) + C(Neighborhood) + C(ExterQual) + C(KitchenQual) + C(BsmtQual)", data=train_new)

# sm.stats.anova_lm(model_reduced.fit(), model_full.fit())

# %%
#변수비교
sm.stats.anova_lm(result2_1, typ=2)
# Out:
#                          sum_sq      df           F         PR(>F)
# C(Neighborhood)        1.875179    24.0    9.521226   3.712895e-32
# C(ExterQual)           0.053279     3.0    2.164201   9.048405e-02
# C(KitchenQual)         0.392355     3.0   15.937467   3.489500e-10
# C(BsmtQual)            1.280837     4.0   39.020719   6.317242e-31
# scale(MasVnrArea)      0.000827     1.0    0.100719   7.510178e-01
# scale(EnclosedPorch)   0.016727     1.0    2.038315   1.536139e-01
# scale(BsmtFinSF1)      0.252062     1.0   30.716248   3.595813e-08
# scale(GarageCars)      0.633782     1.0   77.232771   4.592676e-18
# scale(BsmtFullBath)    0.297954     1.0   36.308752   2.176085e-09
# scale(Fireplaces)      0.268543     1.0   32.724629   1.309629e-08
# scale(TotalBsmtSF)     1.101518     1.0  134.231097   1.215084e-29
# scale(ScreenPorch)     0.162135     1.0   19.757770   9.520390e-06
# scale(WoodDeckSF)      0.154043     1.0   18.771636   1.584036e-05
# scale(LotArea)         1.824058     1.0  222.279901   1.322323e-46
# scale(YearBuilt)       1.535473     1.0  187.112918   5.927862e-40
# scale(GrLivArea)       6.893569     1.0  840.050915  1.287558e-143
# scale(KitchenAbvGr)    0.332970     1.0   40.575723   2.598793e-10
# scale(FullBath)        0.067626     1.0    8.240916   4.160403e-03
# scale(OverallQual)     1.408530     1.0  171.643639   5.619147e-37
# scale(OverallCond)     3.128136     1.0  381.194926   7.401243e-75
# Residual              10.930568  1332.0         NaN            NaN

# %%
# result2_2 = model2_1.fit_regularized(alpha=0.01, L1_wt=1)
# print(result2_2.params)

# %% [markdown]
# - RMSE

# %%
train_new2 = train_new.drop(['SalePrice'], axis=1)

y_train_new2 = result2_1.predict(train_new2)
y_train_new2 = np.exp(y_train_new2)
y_train_new2 = np.array(y_train_new2)
print(y_train_new2)
# Out:
# [204829.17859765 199593.10347479 221994.79505875 ... 258012.68614283
#  134438.09239281 146397.19460761]

# %%
y_train_new = np.array(y_train_new)
y_train_new = np.exp(y_train_new)
print(y_train_new)
# Out:
# [208501. 181501. 223501. ... 266501. 142126. 147501.]

# %%
sm.tools.eval_measures.rmse(y_train_new, y_train_new2, axis=0)
# Out:
# 17670.62001025187

# %% [markdown]
# - 잔차 정규성

# %%
test_norm = sms.omni_normtest(result2_1.resid)
for xi in zip(['Chi^2', 'P-value'], test_norm):
    print("%-12s: %6.3f" % xi)
# Out:
# Chi^2       : 65.640
# P-value     :  0.000

# %%
sp.stats.probplot(result2_1.resid, plot=plt)
plt.show()

# %%
# select_new = ['EnclosedPorch', '1stFlrSF', 'BsmtFinSF1', 'GarageCars', 'YearRemodAdd', 'BsmtFullBath', 'MasVnrArea', 'Fireplaces', 'TotalBsmtSF', 'PoolArea', 'OverallCond', 'ScreenPorch', 'WoodDeckSF', 'LotArea', 'YearBuilt', 'GarageArea', 'GrLivArea', 'KitchenAbvGr', 'TotRmsAbvGrd', 'FullBath', 'GarageYrBlt', 'OverallQual'] 
select_new2 = ['Neighborhood', 'ExterQual', 'KitchenQual', 'BsmtQual']

# %%
test_new = test[select_VIF]
test_new = np.log1p(test_new)

# test_new = test_new.drop(['1stFlrSF'], axis=1)

test_new2 = test[select_new2]

test_new = pd.concat([test_new, test_new2], axis=1)
test_new.tail()
# test_new = pd.get_dummies(test_new)

# test_new = sm.add_constant(test_new)
# Out:
#       MasVnrArea  EnclosedPorch  BsmtFinSF1  GarageCars  BsmtFullBath  \
# 2914    0.000000            0.0    0.000000    0.000000      0.000000
# 2915    0.000000            0.0    5.533389    0.693147      0.000000
# 2916    0.000000            0.0    7.110696    1.098612      0.693147
# 2917    0.000000            0.0    5.823046    0.000000      0.000000
# 2918    4.553877            0.0    6.632002    1.386294      0.000000
#
#       Fireplaces  TotalBsmtSF  ScreenPorch  WoodDeckSF   LotArea  YearBuilt  \
# 2914    0.000000     6.304449          0.0    0.000000  7.568896   7.586296
# 2915    0.000000     6.304449          0.0    0.000000  7.546974   7.586296
# 2916    0.693147     7.110696          0.0    6.163315  9.903538   7.581210
# 2917    0.000000     6.816736          0.0    4.394449  9.253591   7.597396
# 2918    0.693147     6.904751          0.0    5.252273  9.172431   7.597898
#
#       GrLivArea  KitchenAbvGr  FullBath  OverallQual  OverallCond  \
# 2914   6.996681      0.693147  0.693147     1.609438     2.079442
# 2915   6.996681      0.693147  0.693147     1.609438     1.791759
# 2916   7.110696      0.693147  0.693147     1.791759     2.079442
# 2917   6.878326      0.693147  0.693147     1.791759     1.791759
# 2918   7.601402      0.693147  1.098612     2.079442     1.791759
#
#      Neighborhood ExterQual KitchenQual BsmtQual
# 2914      MeadowV        TA          TA       TA
# 2915      MeadowV        TA          TA       TA
# 2916      Mitchel        TA          TA       TA
# 2917      Mitchel        TA          TA       Gd
# 2918      Mitchel        TA          TA       Gd

# %%
x = x_train_new.columns
y = test_new.columns

print(set(y) - set(x))
# Out:
# set()

# %%
y_new = result2_1.predict(test_new)
y_new = np.exp(y_new)
y_new = np.array(y_new)
print(y_new)
# Out:
# [126021.56146147 162653.56217127 183946.2374009  ... 175203.64738805
#  117950.16548491 208912.32627079]

# %%
submission = pd.read_csv("sample_submission.csv")

submission["SalePrice"] = y_new

print(submission.shape)
submission.head()
# Out:
# (1459, 2)
#      Id      SalePrice
# 0  1461  126021.561461
# 1  1462  162653.562171
# 2  1463  183946.237401
# 3  1464  200688.754065
# 4  1465  197239.418740

# %%
# submission.to_csv("18_submission.csv", index=False)
